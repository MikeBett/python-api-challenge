# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import os
import time
import random
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import numpy as np
from scipy.stats import linregress
from citipy import citipy
from api_keys import weather_api_key
from api_keys import g_key
from datetime import datetime

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['busselton',
#  'kavaratti',
#  'ancud',
#  'amderma',
#  'bethel',
#  'barrow',
#  'gujar khan',
#  'taolanaro',
#  'broken hill',
#  'mahebourg',
#  'mount isa',
#  'tumannyy',
#  'barentsburg',
#  'georgetown',
#  'atuona',
#  'nikolskoye',
#  'bluff',
#  'rikitea',
#  'albany',
#  'puerto ayora',
#  'port elizabeth',
#  'east london',
#  'lavrentiya',
#  'ushuaia',
#  'lebu',
#  'am timan',
#  'port alfred',
#  'muravlenko',
#  'khatanga',
#  'belushya guba',
#  'hithadhoo',
#  'ulaanbaatar',
#  'kavieng',
#  'hobart',
#  'port hedland',
#  'port said',
#  'saint-augustin',
#  'taltal',
#  'avarua',
#  'chokurdakh',
#  'cherskiy',
#  'naze',
#  'faanui',
#  'the valley',
#  'bredasdorp',
#  'yellowknife',
#  'castro',
#  'faya',
#  'bambous virieux',
#  'hilo',
#  'artyk',
#  'villa altagracia',
#  'punta arenas',
#  'torbay',
#  'khandyga',
#  'guaramirim',
#  'katsuura',
#  'kawalu',
#  'araouane',
#  'gat',
#  'pathein',
#  'lagodekhi',
#  'treinta y tres',
#  'salinopolis',
#  'norman wells',
#  'rudnogorsk',
#  'new norfolk',
#  'nome',
#  'hermanus',
#  'thompson',
#  'diu',
#  'jamestown',
#  'chuy',
#  'airai',
#  'borogontsy',
#  'anchorage',
#  'nizhneyansk',
#  'ponta do sol',
#  'qaqortoq',
#  'cape town',
#  'yuanping',
#  'rorvik',
#  'puerto del rosario',
#  'kloulklubed',
#  'la ronge',
#  'upernavik',
#  'saint-philippe',
#  'mar del plata',
#  'butaritari',
#  'bodden town',
#  'sao miguel do araguaia',
#  'kenai',
#  'san cristobal',
#  'mount gambier',
#  'blonduos',
#  'ericeira',
#  'provideniya',
#  'kodiak',
#  'yerbogachen',
#  'sola',
#  'pirapora',
#  'mokobeng',
#  'tuktoyaktuk',
#  'arraial do cabo',
#  'kahului',
#  'nanortalik',
#  'soyo',
#  'sinnamary',
#  'mataura',
#  'umm kaddadah',
#  'sakakah',
#  'komsomolskiy',
#  'kapaa',
#  'dalvik',
#  'longyearbyen',
#  'pundaguitan',
#  'ballina',
#  'itoman',
#  'illoqqortoormiut',
#  'evensk',
#  'belaya gora',
#  'los llanos de aridane',
#  'tome-acu',
#  'esperance',
#  'roma',
#  'san carlos de bariloche',
#  'dikson',
#  'teguise',
#  'svetlyy',
#  'havelock',
#  'peniche',
#  'ixtapa',
#  'kadykchan',
#  'iquique',
#  'songea',
#  'fortuna',
#  'sitka',
#  'saldanha',
#  'ascension',
#  'aksarka',
#  'vaini',
#  'krasnoselkup',
#  'coroico',
#  'victoria',
#  'muros',
#  'wewak',
#  'rungata',
#  'netivot',
#  'aulnoye-aymeries',
#  'weiser',
#  'aripuana',
#  'husavik',
#  'mackay',
#  'bengkulu',
#  'tabiauea',
#  'luwuk',
#  'souillac',
#  'tigil',
#  'chalon-sur-saone',
#  'alihe',
#  'caravelas',
#  'porto de moz',
#  'geraldton',
#  'shenjiamen',
#  'marystown',
#  'abha',
#  'lancaster',
#  'sisimiut',
#  'saskylakh',
#  'iqaluit',
#  'avera',
#  'pangnirtung',
#  'karpathos',
#  'virginia beach',
#  'yambio',
#  'iguape',
#  'noumea',
#  'kazalinsk',
#  'tasiilaq',
#  'olafsvik',
#  'tiksi',
#  'nakhon phanom',
#  'mbini',
#  'oytal',
#  'brae',
#  'burica',
#  'barranca',
#  'zelenoborsk',
#  'yangjiang',
#  'sakaraha',
#  'niort',
#  'palabuhanratu',
#  'tres arroyos',
#  'rio gallegos',
#  'haibowan',
#  'port lincoln',
#  'himora',
#  'cumaral',
#  'sumbawa',
#  'lata',
#  'saint-francois',
#  'lazaro cardenas',
#  'carnarvon',
#  'sao filipe',
#  'silver city',
#  'pecos',
#  'galle',
#  'enniscorthy',
#  'sungaipenuh',
#  'qaanaaq',
#  'palia kalan',
#  'bowen',
#  'santa maria',
#  'sentyabrskiy',
#  'koshki',
#  'adrar',
#  'sterling',
#  'beringovskiy',
#  'baruun-urt',
#  'fare',
#  'sabang',
#  'santa rosa',
#  'kaitangata',
#  'posadas',
#  'vestmannaeyjar',
#  'acapulco',
#  'ribeira grande',
#  'deputatskiy',
#  'vanavara',
#  'koungheul',
#  'gawler',
#  'bigaan',
#  'touros',
#  'attawapiskat',
#  'nabire',
#  'moerai',
#  'nizhniy kuranakh',
#  'vieques',
#  'bonthe',
#  'egvekinot',
#  'savona',
#  'fort nelson',
#  'rodeo',
#  'lagoa',
#  'danjiangkou',
#  'mumford',
#  'korla',
#  'sao joao da barra',
#  'tahta',
#  'lewistown',
#  'saint george',
#  'sorland',
#  'grand river south east',
#  'razole',
#  'neiafu',
#  'hami',
#  'koumac',
#  'mayya',
#  'simplicio mendes',
#  'klaksvik',
#  'verkhovye',
#  'meulaboh',
#  'college',
#  'samusu',
#  'cayenne',
#  'gardendale',
#  'tuatapere',
#  'mocambique',
#  'safwah',
#  'sobolevo',
#  'shiraoi',
#  'kathu',
#  'coihaique',
#  'marzuq',
#  'tsihombe',
#  'road town',
#  'novaya bryan',
#  'talnakh',
#  'berbera',
#  'catacocha',
#  'campbeltown',
#  'kabanjahe',
#  'bud',
#  'champerico',
#  'solnechnyy',
#  'yeppoon',
#  'shieli',
#  'leningradskiy',
#  'cockburn town',
#  'devonport',
#  'torrox',
#  'kapiri mposhi',
#  'abu zabad',
#  'terrace',
#  'lompoc',
#  'karachi',
#  'salalah',
#  'dondo',
#  'samarai',
#  'maunabo',
#  'san quintin',
#  'vanderhoof',
#  'trairi',
#  'ilulissat',
#  'griffith',
#  'chor',
#  'constitucion',
#  'vila velha',
#  'diamantino',
#  'along',
#  'namibe',
#  'rio bueno',
#  'springbok',
#  'juba',
#  'verkhnyaya toyma',
#  'lorsch',
#  'abu kamal',
#  'vao',
#  'kazerun',
#  'saint-joseph',
#  'aquiraz',
#  'ballinrobe',
#  'krasnyy chikoy',
#  'athabasca',
#  'owensboro',
#  'cidreira',
#  'broome',
#  'bac',
#  'pisco',
#  'batemans bay',
#  'belyy yar',
#  'cartagena del chaira',
#  'hasaki',
#  'calbuco',
#  'icusesti',
#  'urut',
#  'yagodnoye',
#  'jiayuguan',
#  'auki',
#  'umzimvubu',
#  'sept-iles',
#  'marsh harbour',
#  'soe',
#  'waitati',
#  'vaitupu',
#  'san pedro',
#  'zhezkazgan',
#  'khonsa',
#  'mount darwin',
#  'mariani',
#  'andevoranto',
#  'rio branco',
#  'saleaula',
#  'yulara',
#  'yenagoa',
#  'huilong',
#  'samalaeulu',
#  'smithers',
#  'mpulungu',
#  'hailar',
#  'mangrol',
#  'davila',
#  'moratuwa',
#  'san antonio',
#  'khorinsk',
#  'tateyama',
#  'daru',
#  'saint-raphael',
#  'mount pleasant',
#  'mendi',
#  'dakar',
#  'kamskiye polyany',
#  'vila franca do campo',
#  'arvika',
#  'honiara',
#  'blenheim',
#  'bongandanga',
#  'praya',
#  'dunedin',
#  'bukama',
#  'haines junction',
#  'kamenskoye',
#  'jabiru',
#  'aklavik',
#  'jos',
#  'hamilton',
#  'bundaberg',
#  'lamar',
#  'severo-kurilsk',
#  'zinder',
#  'alofi',
#  'san vicente de canete',
#  'port hardy',
#  'male',
#  'skjervoy',
#  'pa sang',
#  'upata',
#  'huarmey',
#  'necochea',
#  'sampit',
#  'kruisfontein',
#  'kununurra',
#  'walvis bay',
#  'mayskiy',
#  'miri',
#  'a',
#  'sapa',
#  'altamira',
#  'challans',
#  'parras',
#  'ketchikan',
#  'clyde river',
#  'mabaruma',
#  'parabel',
#  'leh',
#  'rovaniemi',
#  'lorengau',
#  'fort saint james',
#  'puerto carreno',
#  'callaguip',
#  'rafaela',
#  'mlowo',
#  'cabo san lucas',
#  'garm',
#  'haapsalu',
#  'isangel',
#  'shu',
#  'tarudant',
#  'boa vista',
#  'vestmanna',
#  'tromso',
#  'port-de-paix',
#  'utrecht',
#  'urucara',
#  'lincoln',
#  'zapolyarnyy',
#  'kungalv',
#  'barra do garcas',
#  'molina',
#  'mys shmidta',
#  'romanovo',
#  'khani',
#  'tshikapa',
#  'log',
#  'ust-nera',
#  'arona',
#  'muzhi',
#  'balimo',
#  'krasnoarmeysk',
#  'coquimbo',
#  'san ramon',
#  'anamur',
#  'kegayli',
#  'umm lajj',
#  'pleasanton',
#  'hingatungan',
#  'rancho palos verdes',
#  'lasa',
#  'mantua',
#  'bathsheba',
#  'sai buri',
#  'saint-ambroise',
#  'atherton',
#  'kirksville',
#  'indianola',
#  'axim',
#  'zhangye',
#  'singapore',
#  'nouadhibou',
#  'sortavala',
#  'mahon',
#  'taunggyi',
#  'bosaso',
#  'nguiu',
#  'sindhnur',
#  'guerrero negro',
#  'tual',
#  'katobu',
#  'kachiry',
#  'fairhope',
#  'kirakira',
#  'codrington',
#  'palenque',
#  'maldonado',
#  'luanda',
#  'bur gabo',
#  'karaman',
#  'preobrazheniye',
#  'clones',
#  'kalino',
#  'ulladulla',
#  'bloomfield',
#  'pierre',
#  'stokmarknes',
#  'nhulunbuy',
#  'san juan',
#  'fort frances',
#  'deer lake',
#  'padang',
#  'bubaque',
#  'buraydah',
#  'atambua',
#  'laem sing',
#  'tuban',
#  'tapaua',
#  'salta',
#  'macamic',
#  'berlevag',
#  'lorain',
#  'coari',
#  'luderitz',
#  'talas',
#  'xai-xai',
#  'skagastrond',
#  'tezu',
#  'biak',
#  'rawannawi',
#  'valdez',
#  'chara',
#  'grindavik',
#  'vardo',
#  'nanakuli',
#  'luza',
#  'lac-megantic',
#  'quime',
#  'floresta',
#  'matara',
#  'maceio',
#  'makakilo city',
#  'batesville',
#  'farafangana',
#  'saint-louis',
#  'yaizu',
#  'montepuez',
#  'mayumba',
#  'hvide sande',
#  'salacgriva',
#  'fairbanks',
#  'makat',
#  'marcona',
#  'wanning',
#  'shelburne',
#  'oyotun',
#  'laguna',
#  'ambon',
#  'aksu',
#  'lingsugur',
#  'chumikan',
#  'pulsano',
#  'harper',
#  'arlit',
#  'warkworth',
#  'bermeo',
#  'galesong',
#  'bassano',
#  'nizhniy tsasuchey',
#  'angoche',
#  'atar',
#  'aykhal',
#  'margate',
#  'portland',
#  'beira',
#  'fuyu',
#  'bantry',
#  'halalo',
#  'iskateley',
#  'alugan',
#  'celestun',
#  'sangar',
#  'kashi',
#  'diapaga',
#  'rawson',
#  'riyadh',
#  'khonuu',
#  'phalaborwa',
#  'hutchinson',
#  'ponta delgada',
#  'malinao',
#  'murdochville',
#  'potosi',
#  'tumbi',
#  'alice springs',
#  'koster',
#  'gamba',
#  'palana',
#  'jalu',
#  'port augusta',
#  'esso',
#  'hirara',
#  'berdigestyakh',
#  'maravilha',
#  'chopovychi',
#  'zyryanka',
#  'richards bay',
#  'cap-aux-meules',
#  'cordeiro',
#  'mountain home',
#  'pevek',
#  'mildura',
#  'yumen',
#  'basco',
#  'tura',
#  'suntar',
#  'amahai',
#  'marang',
#  'japura',
#  'taoudenni',
#  'orlik',
#  'alta floresta',
#  'hongjiang',
#  'matai',
#  'pacific grove',
#  'kathmandu',
#  'kovdor',
#  'gimli',
#  'ringe',
#  'norfolk',
#  'half moon bay',
#  'nuevitas',
#  'vieux-habitants',
#  'nurota',
#  'majene',
#  'buenavista',
#  'asau',
#  'bonavista',
#  'conde',
#  'santa ana',
#  'joshimath']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&"
query_url = url + "appid=" + weather_api_key + "&q=" + city

# %%
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2e7be3fbf6a6ca5ee22f83c7998246c"

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | kavaratti
# Processing Record 3 of Set 1 | ancud
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | gujar khan
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | broken hill
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | mount isa
# Processing Record 12 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | lavrentiya
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | am timan
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | muravlenko
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | ulaanbaatar
# Processing Record 33 of Set 1 | kavieng
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | port hedland
# Processing Record 36 of Set 1 | port said
# Processing Record 37 of Set 1 | saint-augustin
# Processing Record 38 of Set 1 | taltal
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | naze
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | the valley
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | hilo
# Processing Record 0 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 2 | villa altagracia
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | khandyga
# Processing Record 5 of Set 2 | guaramirim
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | kawalu
# Processing Record 8 of Set 2 | araouane
# Processing Record 9 of Set 2 | gat
# Processing Record 10 of Set 2 | pathein
# Processing Record 11 of Set 2 | lagodekhi
# Processing Record 12 of Set 2 | treinta y tres
# Processing Record 13 of Set 2 | salinopolis
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | rudnogorsk
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | diu
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | borogontsy
# Processing Record 25 of Set 2 | anchorage
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | qaqortoq
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | yuanping
# Processing Record 31 of Set 2 | rorvik
# Processing Record 32 of Set 2 | puerto del rosario
# Processing Record 33 of Set 2 | kloulklubed
# Processing Record 34 of Set 2 | la ronge
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | bodden town
# Processing Record 40 of Set 2 | sao miguel do araguaia
# Processing Record 41 of Set 2 | kenai
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 45 of Set 2 | ericeira
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | yerbogachen
# Processing Record 49 of Set 2 | sola
# Processing Record 0 of Set 3 | pirapora
# Processing Record 1 of Set 3 | mokobeng
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | soyo
# Processing Record 7 of Set 3 | sinnamary
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | umm kaddadah
# Processing Record 10 of Set 3 | sakakah
# Processing Record 11 of Set 3 | komsomolskiy
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | dalvik
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | pundaguitan
# Processing Record 16 of Set 3 | ballina
# Processing Record 17 of Set 3 | itoman
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | evensk
# Processing Record 20 of Set 3 | belaya gora
# Processing Record 21 of Set 3 | los llanos de aridane
# Processing Record 22 of Set 3 | tome-acu
# City not found. Skipping...
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | roma
# Processing Record 25 of Set 3 | san carlos de bariloche
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | teguise
# Processing Record 28 of Set 3 | svetlyy
# Processing Record 29 of Set 3 | havelock
# Processing Record 30 of Set 3 | peniche
# Processing Record 31 of Set 3 | ixtapa
# Processing Record 32 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 3 | iquique
# Processing Record 34 of Set 3 | songea
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | ascension
# Processing Record 39 of Set 3 | aksarka
# Processing Record 40 of Set 3 | vaini
# Processing Record 41 of Set 3 | krasnoselkup
# Processing Record 42 of Set 3 | coroico
# Processing Record 43 of Set 3 | victoria
# Processing Record 44 of Set 3 | muros
# Processing Record 45 of Set 3 | wewak
# Processing Record 46 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 3 | netivot
# Processing Record 48 of Set 3 | aulnoye-aymeries
# Processing Record 49 of Set 3 | weiser
# Processing Record 0 of Set 4 | aripuana
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | mackay
# Processing Record 3 of Set 4 | bengkulu
# Processing Record 4 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 4 | luwuk
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | tigil
# Processing Record 8 of Set 4 | chalon-sur-saone
# Processing Record 9 of Set 4 | alihe
# Processing Record 10 of Set 4 | caravelas
# Processing Record 11 of Set 4 | porto de moz
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | shenjiamen
# Processing Record 14 of Set 4 | marystown
# Processing Record 15 of Set 4 | abha
# Processing Record 16 of Set 4 | lancaster
# Processing Record 17 of Set 4 | sisimiut
# Processing Record 18 of Set 4 | saskylakh
# Processing Record 19 of Set 4 | iqaluit
# Processing Record 20 of Set 4 | avera
# Processing Record 21 of Set 4 | pangnirtung
# Processing Record 22 of Set 4 | karpathos
# Processing Record 23 of Set 4 | virginia beach
# Processing Record 24 of Set 4 | yambio
# Processing Record 25 of Set 4 | iguape
# Processing Record 26 of Set 4 | noumea
# Processing Record 27 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | nakhon phanom
# Processing Record 32 of Set 4 | mbini
# Processing Record 33 of Set 4 | oytal
# Processing Record 34 of Set 4 | brae
# Processing Record 35 of Set 4 | burica
# City not found. Skipping...
# Processing Record 36 of Set 4 | barranca
# Processing Record 37 of Set 4 | zelenoborsk
# Processing Record 38 of Set 4 | yangjiang
# Processing Record 39 of Set 4 | sakaraha
# Processing Record 40 of Set 4 | niort
# Processing Record 41 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 4 | tres arroyos
# Processing Record 43 of Set 4 | rio gallegos
# Processing Record 44 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | himora
# City not found. Skipping...
# Processing Record 47 of Set 4 | cumaral
# Processing Record 48 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 49 of Set 4 | lata
# Processing Record 0 of Set 5 | saint-francois
# Processing Record 1 of Set 5 | lazaro cardenas
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | silver city
# Processing Record 5 of Set 5 | pecos
# Processing Record 6 of Set 5 | galle
# Processing Record 7 of Set 5 | enniscorthy
# Processing Record 8 of Set 5 | sungaipenuh
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | palia kalan
# Processing Record 11 of Set 5 | bowen
# Processing Record 12 of Set 5 | santa maria
# Processing Record 13 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | koshki
# Processing Record 15 of Set 5 | adrar
# Processing Record 16 of Set 5 | sterling
# Processing Record 17 of Set 5 | beringovskiy
# Processing Record 18 of Set 5 | baruun-urt
# Processing Record 19 of Set 5 | fare
# Processing Record 20 of Set 5 | sabang
# Processing Record 21 of Set 5 | santa rosa
# Processing Record 22 of Set 5 | kaitangata
# Processing Record 23 of Set 5 | posadas
# Processing Record 24 of Set 5 | vestmannaeyjar
# Processing Record 25 of Set 5 | acapulco
# Processing Record 26 of Set 5 | ribeira grande
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | vanavara
# Processing Record 29 of Set 5 | koungheul
# Processing Record 30 of Set 5 | gawler
# Processing Record 31 of Set 5 | bigaan
# Processing Record 32 of Set 5 | touros
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | nabire
# Processing Record 35 of Set 5 | moerai
# Processing Record 36 of Set 5 | nizhniy kuranakh
# Processing Record 37 of Set 5 | vieques
# Processing Record 38 of Set 5 | bonthe
# Processing Record 39 of Set 5 | egvekinot
# Processing Record 40 of Set 5 | savona
# Processing Record 41 of Set 5 | fort nelson
# Processing Record 42 of Set 5 | rodeo
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | danjiangkou
# Processing Record 45 of Set 5 | mumford
# Processing Record 46 of Set 5 | korla
# Processing Record 47 of Set 5 | sao joao da barra
# Processing Record 48 of Set 5 | tahta
# Processing Record 49 of Set 5 | lewistown
# Processing Record 0 of Set 6 | saint george
# Processing Record 1 of Set 6 | sorland
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 6 | razole
# Processing Record 4 of Set 6 | neiafu
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | koumac
# Processing Record 7 of Set 6 | mayya
# Processing Record 8 of Set 6 | simplicio mendes
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | verkhovye
# Processing Record 11 of Set 6 | meulaboh
# Processing Record 12 of Set 6 | college
# Processing Record 13 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 6 | cayenne
# Processing Record 15 of Set 6 | gardendale
# Processing Record 16 of Set 6 | tuatapere
# Processing Record 17 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 6 | sobolevo
# Processing Record 20 of Set 6 | shiraoi
# Processing Record 21 of Set 6 | kathu
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | marzuq
# Processing Record 24 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 6 | road town
# Processing Record 26 of Set 6 | novaya bryan
# Processing Record 27 of Set 6 | talnakh
# Processing Record 28 of Set 6 | berbera
# Processing Record 29 of Set 6 | catacocha
# Processing Record 30 of Set 6 | campbeltown
# Processing Record 31 of Set 6 | kabanjahe
# Processing Record 32 of Set 6 | bud
# Processing Record 33 of Set 6 | champerico
# Processing Record 34 of Set 6 | solnechnyy
# Processing Record 35 of Set 6 | yeppoon
# Processing Record 36 of Set 6 | shieli
# Processing Record 37 of Set 6 | leningradskiy
# Processing Record 38 of Set 6 | cockburn town
# Processing Record 39 of Set 6 | devonport
# Processing Record 40 of Set 6 | torrox
# Processing Record 41 of Set 6 | kapiri mposhi
# Processing Record 42 of Set 6 | abu zabad
# Processing Record 43 of Set 6 | terrace
# Processing Record 44 of Set 6 | lompoc
# Processing Record 45 of Set 6 | karachi
# Processing Record 46 of Set 6 | salalah
# Processing Record 47 of Set 6 | dondo
# Processing Record 48 of Set 6 | samarai
# Processing Record 49 of Set 6 | maunabo
# Processing Record 0 of Set 7 | san quintin
# Processing Record 1 of Set 7 | vanderhoof
# Processing Record 2 of Set 7 | trairi
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | griffith
# Processing Record 5 of Set 7 | chor
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | vila velha
# Processing Record 8 of Set 7 | diamantino
# Processing Record 9 of Set 7 | along
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | rio bueno
# Processing Record 12 of Set 7 | springbok
# Processing Record 13 of Set 7 | juba
# Processing Record 14 of Set 7 | verkhnyaya toyma
# Processing Record 15 of Set 7 | lorsch
# Processing Record 16 of Set 7 | abu kamal
# Processing Record 17 of Set 7 | vao
# Processing Record 18 of Set 7 | kazerun
# Processing Record 19 of Set 7 | saint-joseph
# Processing Record 20 of Set 7 | aquiraz
# Processing Record 21 of Set 7 | ballinrobe
# Processing Record 22 of Set 7 | krasnyy chikoy
# Processing Record 23 of Set 7 | athabasca
# Processing Record 24 of Set 7 | owensboro
# Processing Record 25 of Set 7 | cidreira
# Processing Record 26 of Set 7 | broome
# Processing Record 27 of Set 7 | bac
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | batemans bay
# Processing Record 30 of Set 7 | belyy yar
# Processing Record 31 of Set 7 | cartagena del chaira
# Processing Record 32 of Set 7 | hasaki
# Processing Record 33 of Set 7 | calbuco
# Processing Record 34 of Set 7 | icusesti
# Processing Record 35 of Set 7 | urut
# Processing Record 36 of Set 7 | yagodnoye
# Processing Record 37 of Set 7 | jiayuguan
# Processing Record 38 of Set 7 | auki
# Processing Record 39 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 7 | sept-iles
# Processing Record 41 of Set 7 | marsh harbour
# Processing Record 42 of Set 7 | soe
# Processing Record 43 of Set 7 | waitati
# Processing Record 44 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 7 | san pedro
# Processing Record 46 of Set 7 | zhezkazgan
# Processing Record 47 of Set 7 | khonsa
# Processing Record 48 of Set 7 | mount darwin
# Processing Record 49 of Set 7 | mariani
# Processing Record 0 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 8 | rio branco
# Processing Record 2 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 8 | yulara
# Processing Record 4 of Set 8 | yenagoa
# Processing Record 5 of Set 8 | huilong
# Processing Record 6 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 8 | smithers
# Processing Record 8 of Set 8 | mpulungu
# Processing Record 9 of Set 8 | hailar
# Processing Record 10 of Set 8 | mangrol
# Processing Record 11 of Set 8 | davila
# Processing Record 12 of Set 8 | moratuwa
# Processing Record 13 of Set 8 | san antonio
# Processing Record 14 of Set 8 | khorinsk
# Processing Record 15 of Set 8 | tateyama
# Processing Record 16 of Set 8 | daru
# Processing Record 17 of Set 8 | saint-raphael
# Processing Record 18 of Set 8 | mount pleasant
# Processing Record 19 of Set 8 | mendi
# Processing Record 20 of Set 8 | dakar
# Processing Record 21 of Set 8 | kamskiye polyany
# Processing Record 22 of Set 8 | vila franca do campo
# Processing Record 23 of Set 8 | arvika
# Processing Record 24 of Set 8 | honiara
# Processing Record 25 of Set 8 | blenheim
# Processing Record 26 of Set 8 | bongandanga
# Processing Record 27 of Set 8 | praya
# Processing Record 28 of Set 8 | dunedin
# Processing Record 29 of Set 8 | bukama
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 8 | aklavik
# Processing Record 34 of Set 8 | jos
# Processing Record 35 of Set 8 | hamilton
# Processing Record 36 of Set 8 | bundaberg
# Processing Record 37 of Set 8 | lamar
# Processing Record 38 of Set 8 | severo-kurilsk
# Processing Record 39 of Set 8 | zinder
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | san vicente de canete
# Processing Record 42 of Set 8 | port hardy
# Processing Record 43 of Set 8 | male
# Processing Record 44 of Set 8 | skjervoy
# Processing Record 45 of Set 8 | pa sang
# Processing Record 46 of Set 8 | upata
# Processing Record 47 of Set 8 | huarmey
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | sampit
# Processing Record 0 of Set 9 | kruisfontein
# Processing Record 1 of Set 9 | kununurra
# Processing Record 2 of Set 9 | walvis bay
# Processing Record 3 of Set 9 | mayskiy
# Processing Record 4 of Set 9 | miri
# Processing Record 5 of Set 9 | a
# City not found. Skipping...
# Processing Record 6 of Set 9 | sapa
# Processing Record 7 of Set 9 | altamira
# Processing Record 8 of Set 9 | challans
# Processing Record 9 of Set 9 | parras
# City not found. Skipping...
# Processing Record 10 of Set 9 | ketchikan
# Processing Record 11 of Set 9 | clyde river
# Processing Record 12 of Set 9 | mabaruma
# Processing Record 13 of Set 9 | parabel
# Processing Record 14 of Set 9 | leh
# Processing Record 15 of Set 9 | rovaniemi
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | fort saint james
# Processing Record 18 of Set 9 | puerto carreno
# Processing Record 19 of Set 9 | callaguip
# Processing Record 20 of Set 9 | rafaela
# Processing Record 21 of Set 9 | mlowo
# Processing Record 22 of Set 9 | cabo san lucas
# Processing Record 23 of Set 9 | garm
# City not found. Skipping...
# Processing Record 24 of Set 9 | haapsalu
# Processing Record 25 of Set 9 | isangel
# Processing Record 26 of Set 9 | shu
# Processing Record 27 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 9 | boa vista
# Processing Record 29 of Set 9 | vestmanna
# Processing Record 30 of Set 9 | tromso
# Processing Record 31 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 32 of Set 9 | utrecht
# Processing Record 33 of Set 9 | urucara
# Processing Record 34 of Set 9 | lincoln
# Processing Record 35 of Set 9 | zapolyarnyy
# Processing Record 36 of Set 9 | kungalv
# Processing Record 37 of Set 9 | barra do garcas
# Processing Record 38 of Set 9 | molina
# Processing Record 39 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 9 | romanovo
# Processing Record 41 of Set 9 | khani
# Processing Record 42 of Set 9 | tshikapa
# Processing Record 43 of Set 9 | log
# Processing Record 44 of Set 9 | ust-nera
# Processing Record 45 of Set 9 | arona
# Processing Record 46 of Set 9 | muzhi
# Processing Record 47 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 48 of Set 9 | krasnoarmeysk
# Processing Record 49 of Set 9 | coquimbo
# Processing Record 0 of Set 10 | san ramon
# Processing Record 1 of Set 10 | anamur
# Processing Record 2 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 10 | umm lajj
# Processing Record 4 of Set 10 | pleasanton
# Processing Record 5 of Set 10 | hingatungan
# Processing Record 6 of Set 10 | rancho palos verdes
# Processing Record 7 of Set 10 | lasa
# Processing Record 8 of Set 10 | mantua
# Processing Record 9 of Set 10 | bathsheba
# Processing Record 10 of Set 10 | sai buri
# Processing Record 11 of Set 10 | saint-ambroise
# Processing Record 12 of Set 10 | atherton
# Processing Record 13 of Set 10 | kirksville
# Processing Record 14 of Set 10 | indianola
# Processing Record 15 of Set 10 | axim
# Processing Record 16 of Set 10 | zhangye
# Processing Record 17 of Set 10 | singapore
# Processing Record 18 of Set 10 | nouadhibou
# Processing Record 19 of Set 10 | sortavala
# Processing Record 20 of Set 10 | mahon
# Processing Record 21 of Set 10 | taunggyi
# Processing Record 22 of Set 10 | bosaso
# Processing Record 23 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 10 | sindhnur
# Processing Record 25 of Set 10 | guerrero negro
# Processing Record 26 of Set 10 | tual
# Processing Record 27 of Set 10 | katobu
# Processing Record 28 of Set 10 | kachiry
# Processing Record 29 of Set 10 | fairhope
# Processing Record 30 of Set 10 | kirakira
# Processing Record 31 of Set 10 | codrington
# Processing Record 32 of Set 10 | palenque
# Processing Record 33 of Set 10 | maldonado
# Processing Record 34 of Set 10 | luanda
# Processing Record 35 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 10 | karaman
# Processing Record 37 of Set 10 | preobrazheniye
# Processing Record 38 of Set 10 | clones
# Processing Record 39 of Set 10 | kalino
# Processing Record 40 of Set 10 | ulladulla
# Processing Record 41 of Set 10 | bloomfield
# Processing Record 42 of Set 10 | pierre
# Processing Record 43 of Set 10 | stokmarknes
# Processing Record 44 of Set 10 | nhulunbuy
# Processing Record 45 of Set 10 | san juan
# Processing Record 46 of Set 10 | fort frances
# Processing Record 47 of Set 10 | deer lake
# Processing Record 48 of Set 10 | padang
# Processing Record 49 of Set 10 | bubaque
# Processing Record 0 of Set 11 | buraydah
# Processing Record 1 of Set 11 | atambua
# Processing Record 2 of Set 11 | laem sing
# Processing Record 3 of Set 11 | tuban
# Processing Record 4 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 11 | salta
# Processing Record 6 of Set 11 | macamic
# Processing Record 7 of Set 11 | berlevag
# Processing Record 8 of Set 11 | lorain
# Processing Record 9 of Set 11 | coari
# Processing Record 10 of Set 11 | luderitz
# Processing Record 11 of Set 11 | talas
# Processing Record 12 of Set 11 | xai-xai
# Processing Record 13 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 11 | tezu
# Processing Record 15 of Set 11 | biak
# Processing Record 16 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 11 | valdez
# Processing Record 18 of Set 11 | chara
# Processing Record 19 of Set 11 | grindavik
# Processing Record 20 of Set 11 | vardo
# Processing Record 21 of Set 11 | nanakuli
# Processing Record 22 of Set 11 | luza
# Processing Record 23 of Set 11 | lac-megantic
# Processing Record 24 of Set 11 | quime
# Processing Record 25 of Set 11 | floresta
# Processing Record 26 of Set 11 | matara
# Processing Record 27 of Set 11 | maceio
# Processing Record 28 of Set 11 | makakilo city
# Processing Record 29 of Set 11 | batesville
# Processing Record 30 of Set 11 | farafangana
# Processing Record 31 of Set 11 | saint-louis
# Processing Record 32 of Set 11 | yaizu
# Processing Record 33 of Set 11 | montepuez
# Processing Record 34 of Set 11 | mayumba
# Processing Record 35 of Set 11 | hvide sande
# Processing Record 36 of Set 11 | salacgriva
# Processing Record 37 of Set 11 | fairbanks
# Processing Record 38 of Set 11 | makat
# Processing Record 39 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | shelburne
# Processing Record 42 of Set 11 | oyotun
# Processing Record 43 of Set 11 | laguna
# Processing Record 44 of Set 11 | ambon
# Processing Record 45 of Set 11 | aksu
# Processing Record 46 of Set 11 | lingsugur
# Processing Record 47 of Set 11 | chumikan
# Processing Record 48 of Set 11 | pulsano
# Processing Record 49 of Set 11 | harper
# Processing Record 0 of Set 12 | arlit
# Processing Record 1 of Set 12 | warkworth
# Processing Record 2 of Set 12 | bermeo
# Processing Record 3 of Set 12 | galesong
# Processing Record 4 of Set 12 | bassano
# Processing Record 5 of Set 12 | nizhniy tsasuchey
# Processing Record 6 of Set 12 | angoche
# Processing Record 7 of Set 12 | atar
# Processing Record 8 of Set 12 | aykhal
# Processing Record 9 of Set 12 | margate
# Processing Record 10 of Set 12 | portland
# Processing Record 11 of Set 12 | beira
# Processing Record 12 of Set 12 | fuyu
# Processing Record 13 of Set 12 | bantry
# Processing Record 14 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 12 | iskateley
# Processing Record 16 of Set 12 | alugan
# Processing Record 17 of Set 12 | celestun
# Processing Record 18 of Set 12 | sangar
# Processing Record 19 of Set 12 | kashi
# Processing Record 20 of Set 12 | diapaga
# Processing Record 21 of Set 12 | rawson
# Processing Record 22 of Set 12 | riyadh
# Processing Record 23 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 12 | phalaborwa
# Processing Record 25 of Set 12 | hutchinson
# Processing Record 26 of Set 12 | ponta delgada
# Processing Record 27 of Set 12 | malinao
# Processing Record 28 of Set 12 | murdochville
# Processing Record 29 of Set 12 | potosi
# Processing Record 30 of Set 12 | tumbi
# Processing Record 31 of Set 12 | alice springs
# Processing Record 32 of Set 12 | koster
# Processing Record 33 of Set 12 | gamba
# Processing Record 34 of Set 12 | palana
# Processing Record 35 of Set 12 | jalu
# Processing Record 36 of Set 12 | port augusta
# Processing Record 37 of Set 12 | esso
# Processing Record 38 of Set 12 | hirara
# Processing Record 39 of Set 12 | berdigestyakh
# Processing Record 40 of Set 12 | maravilha
# Processing Record 41 of Set 12 | chopovychi
# Processing Record 42 of Set 12 | zyryanka
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | cap-aux-meules
# Processing Record 45 of Set 12 | cordeiro
# Processing Record 46 of Set 12 | mountain home
# Processing Record 47 of Set 12 | pevek
# Processing Record 48 of Set 12 | mildura
# Processing Record 49 of Set 12 | yumen
# Processing Record 0 of Set 13 | basco
# Processing Record 1 of Set 13 | tura
# Processing Record 2 of Set 13 | suntar
# Processing Record 3 of Set 13 | amahai
# Processing Record 4 of Set 13 | marang
# Processing Record 5 of Set 13 | japura
# Processing Record 6 of Set 13 | taoudenni
# Processing Record 7 of Set 13 | orlik
# Processing Record 8 of Set 13 | alta floresta
# Processing Record 9 of Set 13 | hongjiang
# Processing Record 10 of Set 13 | matai
# Processing Record 11 of Set 13 | pacific grove
# Processing Record 12 of Set 13 | kathmandu
# Processing Record 13 of Set 13 | kovdor
# Processing Record 14 of Set 13 | gimli
# Processing Record 15 of Set 13 | ringe
# Processing Record 16 of Set 13 | norfolk
# Processing Record 17 of Set 13 | half moon bay
# Processing Record 18 of Set 13 | nuevitas
# Processing Record 19 of Set 13 | vieux-habitants
# Processing Record 20 of Set 13 | nurota
# Processing Record 21 of Set 13 | majene
# Processing Record 22 of Set 13 | buenavista
# Processing Record 23 of Set 13 | asau
# Processing Record 24 of Set 13 | bonavista
# Processing Record 25 of Set 13 | conde
# Processing Record 26 of Set 13 | santa ana
# Processing Record 27 of Set 13 | joshimath
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
column_ord = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  busselton -33.6500  115.3333     61.93        71         100        4.27
# 1  kavaratti  10.5669   72.6420     81.91        72          24        1.10
# 2      ancud -41.8697  -73.8203     44.10        81          75       10.42
# 3     bethel  41.3712  -73.4140     53.65        84          75        0.00
# 4     barrow  71.2906 -156.7887     24.82        93         100       21.85
#
#   Country        Date
# 0      AU  1666514489
# 1      IN  1666514491
# 2      CL  1666514491
# 3      US  1666514202
# 4      US  1666514494

# %%
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
dirty_city_data = city_data_df[(city_data_df["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_df.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  busselton -33.6500  115.3333     61.93        71         100        4.27
# 1  kavaratti  10.5669   72.6420     81.91        72          24        1.10
# 2      ancud -41.8697  -73.8203     44.10        81          75       10.42
# 3     bethel  41.3712  -73.4140     53.65        84          75        0.00
# 4     barrow  71.2906 -156.7887     24.82        93         100       21.85
#
#   Country        Date
# 0      AU  1666514489
# 1      IN  1666514491
# 2      CL  1666514491
# 3      US  1666514202
# 4      US  1666514494

# %%
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv('output_data/city.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-value is: 0.07115109075603339

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 20))
# Out:
# The r-value is: 0.00047797102033587117

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-value is: 0.0668745121544912

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-value is: 0.019503585871519912

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-value is: 0.02092555400801621

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))
# Out:
# The r-value is: 0.07440108995586135
